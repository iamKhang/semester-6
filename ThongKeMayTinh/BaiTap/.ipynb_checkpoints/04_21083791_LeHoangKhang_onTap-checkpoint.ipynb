# %% [markdown]
# # Pandas

# %% [markdown]
# **Bài toán:**
# * Người ta lắp đặt thiết bị để đếm số lượng xe đạp đi qua chiều phía đông và phía tây của cây cầu Fremont Bridge theo từng giờ.
# * Chi tiết: https://data.seattle.gov/Transportation/Fremont-Bridge-Bicycle-Counter/65db-xm6k
# ----------------------
# **Tập dữ liệu:**
# * Tập dữ liệu là số lượng xe đạp đi qua cây cầu Fremont Bridge. Dữ liệu này được thu thập tự động thông qua các cảm biến ở 2 lối đi bộ ở phía đông và phía tây của cây cầu. Số lượng xe đạp được tổng hợp theo từng giờ.
# * Tập dữ liệu bao gồm 4 cột:
#     - Date: Thời gian (ngày - giờ): 10/03/2012 12:00:00 AM (Kiểu thời gian)
#     - Fremont Bridge Total: Tổng số xe đi theo cả 2 lối đông và tây (Kiểu số nguyên)
#     - Fremont Bridge East Sidewalk: Số xe đạp đi qua lối phía đông của cầu tương ứng với thời gian (Kiểu số nguyên)
#     - Fremont Bridge West Sidewalk: Số xe đạp đi qua lối phía tây của cầu tương ứng với thời gian (Kiểu số nguyên)

# %% [markdown]
# <!-- 1) Đọc, quan sát và chuẩn hóa dữ liệu -->
# Đọc file dữ liệu "Data_Bicycle_Counter.csv" và thực hiện các yêu cầu sau:
#
# 1.1 Kiểm tra dữ liệu missing

# %% [markdown]
# 1.2 Liệt kê các thời điểm không có dữ liệu (Missing values)

# %% [markdown]
# 1.3 Chuyển đổi dữ liệu cột Date về dạng chuỗi thời gian
#
# 1.4 Thiết lập cột Date làm index cho DataFrame ()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Đọc dữ liệu
df_bicycle = pd.read_csv('Data_Bicycle_Counter.csv')
df_bicycle.info()
print(df_bicycle)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135614 entries, 0 to 135613
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Date                          135614 non-null  object
#  1   Fremont Bridge Total          135593 non-null  float64
#  2   Fremont Bridge East Sidewalk  135593 non-null  float64
#  3   Fremont Bridge West Sidewalk  135593 non-null  float64
# dtypes: float64(3), object(1)
# memory usage: 4.1+ MB
#                           Date  Fremont Bridge Total  \
# 0       10/03/2012 12:00:00 AM                  13.0
# 1       10/03/2012 01:00:00 AM                  10.0
# 2       10/03/2012 02:00:00 AM                   2.0
# 3       10/03/2012 03:00:00 AM                   5.0
# 4       10/03/2012 04:00:00 AM                   7.0
# ...                        ...                   ...
# 135609  08/31/2020 07:00:00 PM                 190.0
# 135610  08/31/2020 08:00:00 PM                 108.0
# 135611  08/31/2020 09:00:00 PM                  33.0
# 135612  08/31/2020 10:00:00 PM                  36.0
# 135613  08/31/2020 11:00:00 PM                   8.0
#
#         Fremont Bridge East Sidewalk  Fremont Bridge West Sidewalk
# 0                                4.0                           9.0
# 1                                4.0                           6.0
# 2                                1.0                           1.0
# 3                                2.0                           3.0
# 4                                6.0                           1.0
# ...                              ...                           ...
# 135609                          79.0                         111.0
# 135610                          58.0                          50.0
# 135611                          11.0                          22.0
# 135612                          14.0                          22.0
# 135613                           2.0                           6.0
#
# [135614 rows x 4 columns]

# %%
# kiểm tra dữ liệu missing bằng isnull() và sum()
df_bicycle[df_bicycle.isnull().any(axis=1)]
# Out:
#                           Date  Fremont Bridge Total  \
# 6105    06/14/2013 09:00:00 AM                   NaN
# 6106    06/14/2013 10:00:00 AM                   NaN
# 12530   03/09/2014 02:00:00 AM                   NaN
# 21266   03/08/2015 02:00:00 AM                   NaN
# 22331   04/21/2015 11:00:00 AM                   NaN
# 22332   04/21/2015 12:00:00 PM                   NaN
# 30170   03/13/2016 02:00:00 AM                   NaN
# 38906   03/12/2017 02:00:00 AM                   NaN
# 47642   03/11/2018 02:00:00 AM                   NaN
# 56378   03/10/2019 02:00:00 AM                   NaN
# 73977   06/14/2013 09:00:00 AM                   NaN
# 73978   06/14/2013 10:00:00 AM                   NaN
# 80402   03/09/2014 02:00:00 AM                   NaN
# 89138   03/08/2015 02:00:00 AM                   NaN
# 90203   04/21/2015 11:00:00 AM                   NaN
# 90204   04/21/2015 12:00:00 PM                   NaN
# 98042   03/13/2016 02:00:00 AM                   NaN
# 106778  03/12/2017 02:00:00 AM                   NaN
# 115514  03/11/2018 02:00:00 AM                   NaN
# 124250  03/10/2019 02:00:00 AM                   NaN
# 132986  03/08/2020 02:00:00 AM                   NaN
#
#         Fremont Bridge East Sidewalk  Fremont Bridge West Sidewalk
# 6105                             NaN                           NaN
# 6106                             NaN                           NaN
# 12530                            NaN                           NaN
# 21266                            NaN                           NaN
# 22331                            NaN                           NaN
# 22332                            NaN                           NaN
# 30170                            NaN                           NaN
# 38906                            NaN                           NaN
# 47642                            NaN                           NaN
# 56378                            NaN                           NaN
# 73977                            NaN                           NaN
# 73978                            NaN                           NaN
# 80402                            NaN                           NaN
# 89138                            NaN                           NaN
# 90203                            NaN                           NaN
# 90204                            NaN                           NaN
# 98042                            NaN                           NaN
# 106778                           NaN                           NaN
# 115514                           NaN                           NaN
# 124250                           NaN                           NaN
# 132986                           NaN                           NaN

# %%
# Liệt kê các thời điểm không có dữ liệu (Missing values)
df_bicycle[df_bicycle.isnull().any(axis=1)]
# Out:
#                           Date  Fremont Bridge Total  \
# 6105    06/14/2013 09:00:00 AM                   NaN
# 6106    06/14/2013 10:00:00 AM                   NaN
# 12530   03/09/2014 02:00:00 AM                   NaN
# 21266   03/08/2015 02:00:00 AM                   NaN
# 22331   04/21/2015 11:00:00 AM                   NaN
# 22332   04/21/2015 12:00:00 PM                   NaN
# 30170   03/13/2016 02:00:00 AM                   NaN
# 38906   03/12/2017 02:00:00 AM                   NaN
# 47642   03/11/2018 02:00:00 AM                   NaN
# 56378   03/10/2019 02:00:00 AM                   NaN
# 73977   06/14/2013 09:00:00 AM                   NaN
# 73978   06/14/2013 10:00:00 AM                   NaN
# 80402   03/09/2014 02:00:00 AM                   NaN
# 89138   03/08/2015 02:00:00 AM                   NaN
# 90203   04/21/2015 11:00:00 AM                   NaN
# 90204   04/21/2015 12:00:00 PM                   NaN
# 98042   03/13/2016 02:00:00 AM                   NaN
# 106778  03/12/2017 02:00:00 AM                   NaN
# 115514  03/11/2018 02:00:00 AM                   NaN
# 124250  03/10/2019 02:00:00 AM                   NaN
# 132986  03/08/2020 02:00:00 AM                   NaN
#
#         Fremont Bridge East Sidewalk  Fremont Bridge West Sidewalk
# 6105                             NaN                           NaN
# 6106                             NaN                           NaN
# 12530                            NaN                           NaN
# 21266                            NaN                           NaN
# 22331                            NaN                           NaN
# 22332                            NaN                           NaN
# 30170                            NaN                           NaN
# 38906                            NaN                           NaN
# 47642                            NaN                           NaN
# 56378                            NaN                           NaN
# 73977                            NaN                           NaN
# 73978                            NaN                           NaN
# 80402                            NaN                           NaN
# 89138                            NaN                           NaN
# 90203                            NaN                           NaN
# 90204                            NaN                           NaN
# 98042                            NaN                           NaN
# 106778                           NaN                           NaN
# 115514                           NaN                           NaN
# 124250                           NaN                           NaN
# 132986                           NaN                           NaN

# %%
# đổi thành tên ngắn gọn
df_bicycle.columns = ['Date','Total', 'East', 'West']
df_bicycle
# Out:
#                           Date  Total  East   West
# 0       10/03/2012 12:00:00 AM   13.0   4.0    9.0
# 1       10/03/2012 01:00:00 AM   10.0   4.0    6.0
# 2       10/03/2012 02:00:00 AM    2.0   1.0    1.0
# 3       10/03/2012 03:00:00 AM    5.0   2.0    3.0
# 4       10/03/2012 04:00:00 AM    7.0   6.0    1.0
# ...                        ...    ...   ...    ...
# 135609  08/31/2020 07:00:00 PM  190.0  79.0  111.0
# 135610  08/31/2020 08:00:00 PM  108.0  58.0   50.0
# 135611  08/31/2020 09:00:00 PM   33.0  11.0   22.0
# 135612  08/31/2020 10:00:00 PM   36.0  14.0   22.0
# 135613  08/31/2020 11:00:00 PM    8.0   2.0    6.0
#
# [135614 rows x 4 columns]

# %%
#Chuyển đổi dữ liệu cột Date về dạng chuỗi thời gian bằng hàm to_datetime()
print(df_bicycle['Date'])
df_bicycle['Date'] = pd.to_datetime(df_bicycle['Date'])
print(df_bicycle['Date'])
print(df_bicycle.dtypes)
# Out:
# 0         10/03/2012 12:00:00 AM
# 1         10/03/2012 01:00:00 AM
# 2         10/03/2012 02:00:00 AM
# 3         10/03/2012 03:00:00 AM
# 4         10/03/2012 04:00:00 AM
#                    ...
# 135609    08/31/2020 07:00:00 PM
# 135610    08/31/2020 08:00:00 PM
# 135611    08/31/2020 09:00:00 PM
# 135612    08/31/2020 10:00:00 PM
# 135613    08/31/2020 11:00:00 PM
# Name: Date, Length: 135614, dtype: object
# C:\Users\iamho\AppData\Local\Temp\ipykernel_16716\1795773676.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_bicycle['Date'] = pd.to_datetime(df_bicycle['Date'])
# 0        2012-10-03 00:00:00
# 1        2012-10-03 01:00:00
# 2        2012-10-03 02:00:00
# 3        2012-10-03 03:00:00
# 4        2012-10-03 04:00:00
#                  ...
# 135609   2020-08-31 19:00:00
# 135610   2020-08-31 20:00:00
# 135611   2020-08-31 21:00:00
# 135612   2020-08-31 22:00:00
# 135613   2020-08-31 23:00:00
# Name: Date, Length: 135614, dtype: datetime64[ns]
# Date     datetime64[ns]
# Total           float64
# East            float64
# West            float64
# dtype: object

# %%
#Thiết lập cột Date làm index cho DataFrame bằng hàm set_index
df_bicycle.set_index('Date')
# Out:
#                      Total  East   West
# Date
# 2012-10-03 00:00:00   13.0   4.0    9.0
# 2012-10-03 01:00:00   10.0   4.0    6.0
# 2012-10-03 02:00:00    2.0   1.0    1.0
# 2012-10-03 03:00:00    5.0   2.0    3.0
# 2012-10-03 04:00:00    7.0   6.0    1.0
# ...                    ...   ...    ...
# 2020-08-31 19:00:00  190.0  79.0  111.0
# 2020-08-31 20:00:00  108.0  58.0   50.0
# 2020-08-31 21:00:00   33.0  11.0   22.0
# 2020-08-31 22:00:00   36.0  14.0   22.0
# 2020-08-31 23:00:00    8.0   2.0    6.0
#
# [135614 rows x 3 columns]

# %% [markdown]
# ### 2) Khám phá tập dữ liệu
# Sử dụng các đặc trưng thống kê

# %%
#Sử dụng sum tính tổng lượt người đi xe đạp
total_people = df_bicycle.sum()['Total']
print(f'Tổng lượt người đi xe đạp qua cầu là {total_people} người')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 #Sử dụng sum tính tổng lượt người đi xe đạp
# ----> 2 total_people = df_bicycle.sum()['Total']
#       3 print(f'Tổng lượt người đi xe đạp qua cầu là {total_people} người')
#
# File c:\Users\iamho\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11312, in DataFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11303 @doc(make_doc("sum", ndim=2))
#   11304 def sum(
#   11305     self,
#    (...)
#   11310     **kwargs,
#   11311 ):
# > 11312     result = super().sum(axis, skipna, numeric_only, min_count, **kwargs)
#   11313     return result.__finalize__(self, method="sum")
#
# File c:\Users\iamho\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12078, in NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12070 def sum(
#   12071     self,
#   12072     axis: Axis | None = 0,
#    (...)
#   12076     **kwargs,
#   12077 ):
# > 12078     return self._min_count_stat_function(
#   12079         "sum", nanops.nansum, axis, skipna, numeric_only, min_count, **kwargs
#   12080     )
#
# File c:\Users\iamho\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12061, in NDFrame._min_count_stat_function(self, name, func, axis, skipna, numeric_only, min_count, **kwargs)
#   12058 elif axis is lib.no_default:
#   12059     axis = 0
# > 12061 return self._reduce(
#   12062     func,
#   12063     name=name,
#   12064     axis=axis,
#   12065     skipna=skipna,
#   12066     numeric_only=numeric_only,
#   12067     min_count=min_count,
#   12068 )
#
# File c:\Users\iamho\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11204, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11200     df = df.T
#   11202 # After possibly _get_data and transposing, we are now in the
#   11203 #  simple case where we can use BlockManager.reduce
# > 11204 res = df._mgr.reduce(blk_func)
#   11205 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11206 if out_dtype is not None and out.dtype != "boolean":
#
# File c:\Users\iamho\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1459, in BlockManager.reduce(self, func)
#    1457 res_blocks: list[Block] = []
#    1458 for blk in self.blocks:
# -> 1459     nbs = blk.reduce(func)
#    1460     res_blocks.extend(nbs)
#    1462 index = Index([None])  # placeholder
#
# File c:\Users\iamho\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py:377, in Block.reduce(self, func)
#     371 @final
#     372 def reduce(self, func) -> list[Block]:
#     373     # We will apply the function and reshape the result into a single-row
#     374     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     375     assert self.ndim == 2
# --> 377     result = func(self.values)
#     379     if self.values.ndim == 1:
#     380         res_values = result
#
# File c:\Users\iamho\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11118, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   11114 if isinstance(values, ExtensionArray):
#   11115     if not is_1d_only_ea_dtype(values.dtype) and not isinstance(
#   11116         self._mgr, ArrayManager
#   11117     ):
# > 11118         return values._reduce(name, axis=1, skipna=skipna, **kwds)
#   11119     has_keepdims = dtype_has_keepdims.get(values.dtype)
#   11120     if has_keepdims is None:
#
# File c:\Users\iamho\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arrays\base.py:1856, in ExtensionArray._reduce(self, name, skipna, keepdims, **kwargs)
#    1854 meth = getattr(self, name, None)
#    1855 if meth is None:
# -> 1856     raise TypeError(
#    1857         f"'{type(self).__name__}' with dtype {self.dtype} "
#    1858         f"does not support reduction '{name}'"
#    1859     )
#    1860 result = meth(skipna=skipna, **kwargs)
#    1861 if keepdims:
#
# TypeError: 'DatetimeArray' with dtype datetime64[ns] does not support reduction 'sum'

# %%
#Thống kê số lượng xe đạp qua cầu phía West
total_people_to_West = df_bicycle.sum()['West']
print(f"Tổng số người đi về phía West là {total_people_to_West} người")
#Trực quan hóa số liệu thống kê (lựa chọn biểu đồ thích hợp để trực quan hóa dữ liệu trên)
plt.pie([df_bicycle.sum()['West'], df_bicycle.sum()['East']], autopct='%1.1f%%')
plt.title("Biểu đồ thể hiện tỉ lệ số người đi về West và East")
plt.show()
# Out:
# Tổng số người đi về phía West là 8344494.0 người

# %% [markdown]
# Nhận xét:
# -
# -
# -

# %% [markdown]
# ### 3) Thống kê tổng số lượng đi xe đạp theo năm để thấy xu hướng chung và rút ra kết luận (tối thiểu 2 kết luận)

# %%
#Dữ liệu bắt đầu từ 3/10/2012 --> 31/08/2020
#Tách dữ liệu chỉ lấy từ năm 2013 - 2019
df_full_year = df_bicycle.loc['2013':'2019']
df_full_year.info()
print(df_full_year)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 20130 to 20189
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    60 non-null     datetime64[ns]
#  1   Total   60 non-null     float64
#  2   East    60 non-null     float64
#  3   West    60 non-null     float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 2.0 KB
#                      Date  Total   East   West
# 20130 2015-01-19 18:00:00  187.0   50.0  137.0
# 20131 2015-01-19 19:00:00   83.0   29.0   54.0
# 20132 2015-01-19 20:00:00   51.0   18.0   33.0
# 20133 2015-01-19 21:00:00   26.0   15.0   11.0
# 20134 2015-01-19 22:00:00   11.0    4.0    7.0
# 20135 2015-01-19 23:00:00   14.0    7.0    7.0
# 20136 2015-01-20 00:00:00   11.0    3.0    8.0
# 20137 2015-01-20 01:00:00    2.0    0.0    2.0
# 20138 2015-01-20 02:00:00    3.0    0.0    3.0
# 20139 2015-01-20 03:00:00    2.0    1.0    1.0
# 20140 2015-01-20 04:00:00    6.0    4.0    2.0
# 20141 2015-01-20 05:00:00   37.0   25.0   12.0
# 20142 2015-01-20 06:00:00   99.0   61.0   38.0
# 20143 2015-01-20 07:00:00  254.0  243.0   11.0
# 20144 2015-01-20 08:00:00  387.0  317.0   70.0
# 20145 2015-01-20 09:00:00  249.0  170.0   79.0
# 20146 2015-01-20 10:00:00   99.0   71.0   28.0
# 20147 2015-01-20 11:00:00   66.0   39.0   27.0
# 20148 2015-01-20 12:00:00   76.0   44.0   32.0
# 20149 2015-01-20 13:00:00   89.0   55.0   34.0
# 20150 2015-01-20 14:00:00  103.0   52.0   51.0
# 20151 2015-01-20 15:00:00  137.0   60.0   77.0
# 20152 2015-01-20 16:00:00  223.0   95.0  128.0
# 20153 2015-01-20 17:00:00  444.0  133.0  311.0
# 20154 2015-01-20 18:00:00  367.0  112.0  255.0
# 20155 2015-01-20 19:00:00  146.0   53.0   93.0
# 20156 2015-01-20 20:00:00   50.0   16.0   34.0
# 20157 2015-01-20 21:00:00   39.0   20.0   19.0
# 20158 2015-01-20 22:00:00   21.0   10.0   11.0
# 20159 2015-01-20 23:00:00   17.0    4.0   13.0
# 20160 2015-01-21 00:00:00   14.0    8.0    6.0
# 20161 2015-01-21 01:00:00    1.0    0.0    1.0
# 20162 2015-01-21 02:00:00    3.0    2.0    1.0
# 20163 2015-01-21 03:00:00    2.0    2.0    0.0
# 20164 2015-01-21 04:00:00    5.0    4.0    1.0
# 20165 2015-01-21 05:00:00   29.0   21.0    8.0
# 20166 2015-01-21 06:00:00  106.0   72.0   34.0
# 20167 2015-01-21 07:00:00  205.0  192.0   13.0
# 20168 2015-01-21 08:00:00  336.0  335.0    1.0
# 20169 2015-01-21 09:00:00  191.0  191.0    0.0
# 20170 2015-01-21 10:00:00   72.0   72.0    0.0
# 20171 2015-01-21 11:00:00   43.0   43.0    0.0
# 20172 2015-01-21 12:00:00   56.0   55.0    1.0
# 20173 2015-01-21 13:00:00   61.0   61.0    0.0
# 20174 2015-01-21 14:00:00   82.0   76.0    6.0
# 20175 2015-01-21 15:00:00   92.0   51.0   41.0
# 20176 2015-01-21 16:00:00  224.0   90.0  134.0
# 20177 2015-01-21 17:00:00  377.0   99.0  278.0
# 20178 2015-01-21 18:00:00  360.0  118.0  242.0
# 20179 2015-01-21 19:00:00  140.0   46.0   94.0
# 20180 2015-01-21 20:00:00   59.0   24.0   35.0
# 20181 2015-01-21 21:00:00   53.0   22.0   31.0
# 20182 2015-01-21 22:00:00   30.0   15.0   15.0
# 20183 2015-01-21 23:00:00   11.0    3.0    8.0
# 20184 2015-01-22 00:00:00   12.0    3.0    9.0
# 20185 2015-01-22 01:00:00    1.0    0.0    1.0
# 20186 2015-01-22 02:00:00    3.0    0.0    3.0
# 20187 2015-01-22 03:00:00    3.0    1.0    2.0
# 20188 2015-01-22 04:00:00    5.0    4.0    1.0
# 20189 2015-01-22 05:00:00   23.0   18.0    5.0

# %%
#Tổng hợp số liệu chuỗi thời gian theo từng năm
#Tính tổng số lượt qua cầu theo năm
# Group the data by year and calculate the sum of 'Total' for each year
total_crossings_per_year = df_bicycle.groupby(df_bicycle['Date'].dt.year)['Total'].sum()
total_crossings_per_year
# Out:
# Date
# 2012     305422.0
# 2013    1856558.0
# 2014    2012392.0
# 2015    1973112.0
# 2016    1964940.0
# 2017    1926270.0
# 2018    2103760.0
# 2019    2374292.0
# 2020     825081.0
# Name: Total, dtype: float64

# %%
#Trực quan hóa trên biểu đồ, lựa chọn biểu đồ thích hợp
total_crossings_per_year.plot(kind='bar')
plt.xlabel("Năm")
plt.ylabel("Tổng số người")
plt.show()

# %% [markdown]
# Nhận xét:
# -
# -
# -

# %% [markdown]
# ### 4) Thống kê số lượng người đi xe đạp theo tháng để thấy xu hướng mùa vụ và rút ra kết luận (tối thiểu 2 kết luận)

# %%
#Thống kê số lượng xe theo tháng qua phía Đông, Tây và Toàn bộ
data_month= df_bicycle.groupby(df_bicycle['Date'].dt.month)['Total'].sum()
data_month
# Out:
# Date
# 1      914770.0
# 2      834652.0
# 3     1090500.0
# 4     1275712.0
# 5     1707022.0
# 6     1645745.0
# 7     1771661.0
# 8     1702713.0
# 9     1336996.0
# 10    1333480.0
# 11     997500.0
# 12     731076.0
# Name: Total, dtype: float64

# %%
#Trực quan hóa trên biểu đồ, lựa chọn biểu đồ thích hợp
data_month.plot(kind='bar')

plt.show()

# %%
#Hiển thị chi tiết dữ liệu theo tháng của một năm cụ thể [2019].
df_2019 = df_bicycle.loc[df_bicycle.get('Date').dt.year == 2019]
data_month_2019 = df_2019.groupby(df_2019["Date"].dt.month)["Total"].sum()
#Trực quan hóa trên biểu đồ, lựa chọn biểu đồ thích hợp\
data_month_2019.plot(kind="bar")
plt.title("Biểu đồ thể hiện tổng lượt người đi qua cầu trong năm 2019")
plt.xlabel("Tháng")
plt.ylabel("Người")
plt.show()

# %% [markdown]
# Nhận xét:
# -
# -
# -

# %% [markdown]
# ### 5) Thống kê lượng đi xe đạp theo giờ và rút ra kết luận (tối thiểu 2 kết luận)

# %%
#Tính trung bình lượng xe theo từng giờ qua cầu trong toàn bộ tập dữ liệu sử dụng groupby
by_time = df_bicycle.groupby(df_bicycle["Date"].dt.hour)["Total"].mean()
by_time
# Out:
# Date
# 0      11.304902
# 1       5.984074
# 2       3.938453
# 3       2.903557
# 4       6.487878
# 5      25.589630
# 6      89.945496
# 7     227.002831
# 8     322.147231
# 9     188.577093
# 10    100.344840
# 11     89.222340
# 12     95.248008
# 13    101.929747
# 14    111.129204
# 15    141.325841
# 16    232.995752
# 17    389.189381
# 18    264.838761
# 19    130.602301
# 20     75.016991
# 21     47.885133
# 22     31.201770
# 23     20.508142
# Name: Total, dtype: float64

# %%
#Trực quan hóa dữ liệu:
by_time.plot(kind="line")
plt.title("Biểu đồ thể hiện lượt người đi qua cầu theo giờ")
plt.xlabel("Giờ")
plt.ylabel("Lượt người")
plt.show()

# %% [markdown]
# Nhận xét:
# -
# -
# -

# %% [markdown]
# ### 6) Thống kê lượng xe trung bình theo ngày trong tuần và rút ra kết luận (tối thiểu 2 kết luận)

# %%
#Nhóm dữ liệu theo ngày trong tuần và tính trung bình sử dụng groupby và mean
df_weekday = df_bicycle.groupby(df_bicycle["Date"].dt.weekday)["Total"].mean()
#Đổi tên index theo ngày dễ quan sát
df_weekday.index = ['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun']
df_weekday
# Out:
# Mon      132.039395
# Tues     140.619442
# Wed      139.598217
# Thurs    132.737108
# Fri      120.132101
# Sat       64.290376
# Sun       62.537484
# Name: Total, dtype: float64

# %%
# Convert the index to datetime type
df_bicycle.index = pd.to_datetime(df_bicycle.index)

# Continue with the rest of the code
df_weekend = np.where(df_bicycle.index.weekday < 5, 'Weekday', 'Weekend')
df_weekday = df_bicycle.groupby(df_weekend)['Total'].mean()
by_time_weekend = df_bicycle.groupby([df_weekend, df_bicycle.index.hour])['Total'].mean()


df_weekday
df_weekend
# Out:
# array(['Weekday', 'Weekday', 'Weekday', ..., 'Weekday', 'Weekday',
#        'Weekday'], dtype='<U7')

# %%
#Trực quan hóa dữ liệu
df_weekday.plot(kind="bar")
plt.title("Biểu đồ thể hiện lượt người đi qua cầu theo ngày")
plt.xlabel("Ngày")
plt.ylabel("Lượt người")
plt.show()

# %% [markdown]
# Nhận xét:
# -
# -
# -
